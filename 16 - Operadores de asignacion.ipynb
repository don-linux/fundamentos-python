# %% [markdown]
# # Operadores de asignación
#
# En Python, los operadores de asignación se utilizan para asignar valores a las variables.

# %% [markdown]
# ## Asignación simple y reasignación

# %%
x = 100
x = x + 3

# %% [markdown]
# ## Operadores de asignación
#
# Los operadores de asignación pueden usarse con números o con otras variables.
# Este operador realizará la operación y asignará el resultado a la variable.

# %%
x += z
x += 3
x -= 2
x *= 4
x /= 2
x %= 3
x //= 2
x **= 3

# %% [markdown]
# ## Operador walrus
#
# Representado con `:=`.
#
# Este es el operador de asignación de expresión, también conocido como el operador walrus, que permite asignar valores a las variables como parte de una expresión.

# %%
print(y := 2)
