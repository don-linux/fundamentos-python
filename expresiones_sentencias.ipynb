# %% [markdown]
# # Expresiones y sentencias

# %% [markdown]
# ## Expresiones (expressions)
#
# Son cualquier cosa que produce o que tiene un valor. Algo que se puede "evaluar" y da un resultado.

# %% [markdown]
# ### Ejemplos de expresiones
#
# ```python
# 1 + 2 # Operación aritmética
# "hola".upper() # Llamada a método
# x # Variable
# x > 10 # Comparación
# len([1, 2, 3]) # Llamada a función
# z := 3 # Asignación con operador walrus (Python 3.8+)
# ```
#
# Si lo puedes asignar o usar dentro de un `print`, probablemente es una expresión.

# %% [markdown]
# ## Sentencias (statements)
#
# Una sentencia es una instrucción completa que Python ejecuta, pero no es un valor en sí misma. Es decir, son las órdenes que le das al intérprete: "Haz algo con este dato".
#
# Si es parte de la estructura del programa, es una sentencia.

# %% [markdown]
# ### Ejemplos de sentencias

# %% [markdown]
# #### Asignación de variable

# %%
x = 3

# %% [markdown]
# #### Funciones

# %%
def foo():
    return 123

# %% [markdown]
# #### Clases

# %%
class MiClase:
    pass

# %% [markdown]
# #### Sentencias de control

# %%
if x > 10:
    print("grande")

# %% [markdown]
# #### Ciclo

# %%
for i in range(5):
    print(i)

# %% [markdown]
# #### Try/Except

# %%
try:
    resultado = 10 / 0
except ZeroDivisionError:
    print("No puedes dividir entre cero.")

# %% [markdown]
# #### Importaciones

# %%
import math

# %% [markdown]
# ## Diferencia clave
#
# No puedes guardar una sentencia dentro de una expresión, pero puedes guardar una expresión dentro de una sentencia.
#
# ```python
# print(x = 3) # SyntaxError
# print(1 + 2) # Resultado: 3
# print(z := 2) # Resultado: 2
# ```
